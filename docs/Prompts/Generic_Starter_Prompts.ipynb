# %% [markdown]
# # Option 1 - Create the DDL Specifiation
#
# Please use the following prompt file and follow the instructions in it:
#
# - hrs_dbx_repo/docs/Prompts/01 Prompt HRS Gold Desc BMI DDL Spec.ipynb/
#
# Then provide a summary list input files used and deliverables created.

# %% [markdown]
# or

# %% [markdown]
# # Option 1 - Generate only the SQL DDL, no DDL specificaition
#
# Please use the following prompt file and follow the instructions in it:
#
# - hrs_dbx_repo/docs/Prompts/01 Prompt HRS Gold Desc BMI DDL Only.ipynb/
#
# Then provide a summary list input files used and deliverables created.

# %% [markdown]
# # Option 3 - Generate DDL specificaition followed by the SQL DDL Statement
#
# Please use the following prompt file and follow the instructions in it:
#
# - hrs_dbx_repo/docs/Prompts/01 Prompt HRS Gold Desc BMI DDL Only.ipynb/
#
# Then provide a summary list input files used and deliverables created.
