# %% [markdown]
# # Gold DDL Option 1 - Generate the Gold DDL Specification Document
#
# Please use the following prompt file and follow the instructions in it:
#
# - `hrs_dbx_repo/docs/Prompts/01 Prompt Generate HRS Gold BMI DDL Spec.ipynb/`
#
# Then provide a summary list input files used and deliverables created.

# %% [markdown]
# or

# %% [markdown]
# # Gold DDL Option 2 - Generate the Gold DDL SQL Script
#
# Please use the following prompt file and follow the instructions in it:
#
# - `hrs_dbx_repo/docs/Prompts/01 Prompt HRS Gold BMI DDL Script.ipynb/`
#
# Then provide a summary list input files used and deliverables created.

# %% [markdown]
# # SLV DDL Option 1 - Generate the Silver DDL Specification Document
#
# Please use the following prompt file and follow the instructions in it:
#
# - `hrs_dbx_repo/docs/Prompts/01 Prompt HRS SLV DDL Gen.ipynb/`
#
# Your Deliverable:
# DDL Specification document that can be used by a DBA or AI Assistant to geneate the DDL SQL Script.
# > - `\hrs_dbx_repo\notebooks\HRS Gold_Data_Model_Specifications\HRS Gold BMI Descriptive Stats.ipynb`
#
# Then provide a summary list input files used and deliverables created.

# %% [markdown]
# # SLV DDL Option 2 - Generate the Silver DDL SQL Script
#
# Please use the following prompt file and follow the instructions in it:
#
# * `hrs_dbx_repo/docs/Prompts/01 Prompt HRS SLV DDL Gen.ipynb/`
#
# Your Deliverables:
# DDL SQL script that can be used to create the Databricks delta table.
# > 1. `<\hrs_dbx_repo\sql\ddl\create_hrs_demographics_v2.sql>`
#
# Then provide a summary of input files used and deliverables created.
