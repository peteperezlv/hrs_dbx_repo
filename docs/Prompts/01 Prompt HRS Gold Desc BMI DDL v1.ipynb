# %% [markdown]
# Prompt:
# You are a Databricks data anlyst and have been tasked to create one output.
#
# > 1. A DDL specification document that can be used by AI Agents to generate the SQL DDL statement.
#
# You have two documents to work with for your task.
#
# > 1. A Use Case document to understand the user requirements.
# >> - `C:\AI Development\hrs_dbx_repo\docs\Gold Level Use Cases\UC-DA-001 HRS Gold Desc BMI Race Stats.ipynb`
#
# > 2. A SQL DDL Template with details about the DDL definition rules.
# >> - `C:\AI Development\hrs_dbx_repo\docs\Templates and Workflows\10  HRS Gold DDL Master Template v1.ipynb`
#
# Only use the two document provided.  Do not use any other document for your work.
#
# Your Deliverable:
# > - A DDL Specification document based on the SQL DDL Template.
#
# > - Document Name: `C:\AI Development\hrs_dbx_repo\notebooks\HRS Gold_Data_Model_Specifications\10 HRS_Gold_Desc_BMI_DDL_Spec.ipynb.`
#
#
# Template Inputs:
#
# Use the following to guide your analysis and creation of the DDL Specification.
#
# # 1. Specification Document Information
# 	Author: Pete Perez
#
# # 5. Analytical Use Case
# 	Use Case Document: 	UC-DA-001 HRS Gold Desc BMI Race Stats.ipynb
#
#
# # 7. Gold Table Type Properties
# 	GOLD_TABLE_TYPE: Analytical
# 	ANALYTICAL_ROLE: Aggregate Statistics
# 	ANALYTICAL_PURPOSE: Store descriptive BMI statistics by cohort, wave, race, and gender
#
# # 9. Target Table Parameters
# 	TARGET_TABLE_NAME: analytic_hrs_bmi_stats
# 	TARGET_TABLE_COMMENT
#
# ## 12.1 Keys Business Attributes
# 	| Column Name  | Category          | Databricks Type | Nullable | Column Comment               |
# 	| -------------------------------- | --------------- | -------- | ---------------------------- |
# 	| wave_number  | Business Attribute| INT             | Yes      | HRS Wave Number identifier   |
#  	| hacohort     | Business Attribute| IN              | Yes      | HRS cohort identifier        |
#
#
# ## 12.2 Dimension Columns
# 	| Column Name | Category       | Databricks Type | Nullable | Column Comment                  |
# 	|------------ | -------------- | --------------- | -------- |-------------------------------- |
# 	| `raracem`   | Dimension      | INT             | Yes      | RAND HRS race category          |
# 	| `ragender`  | Dimension      | INT             | Yes      | RAND HRS gender category        |
# 	| `agey_e`    | Dimension      | INT             | Yes      | RAND HRS age category           |
#
#
# ## 12.3 Metric Columns
# | Column Name       | Category | Databricks Type | Nullable | Column Comment                                   |
# |------------------ | -------- | --------------- | -------- |------------------------------------------------- |
# | `bmi_count`       | Measure  | INT             | Yes      | Number of records included in the BMI statistics |
# | `bmi_mean`        | Measure  | DOUBLE          | Yes      | Mean BMI                                         |
# | `bmi_min`         | Measure  | DOUBLE          | Yes      | Mean BMI                                         |
# | `bmi_max`         | Measure  | DOUBLE          | Yes      | Mean BMI                                         |
# | `bmi_sd`          | Measure  | DOUBLE          | Yes      | Standard deviation of BMI                        |
# | `bmi_min`         | Measure  | INT             | Yes      | Minimum BMI                                      |
# | `bmi_max`         | Measure  | INT             | Yes      | Maximum BMI                                      |
#
# # 13. Derived Analytical Columns
# 	Derived Analytical Columns Required: No
#
# # 19. DROP TABLE Requirement
# 	DROP TABLE IF EXISTS: Yes
#
# # 25. Structural Validation Requirements
# 	Primary Key: Yes
# 	Foreign Keys: Yes
