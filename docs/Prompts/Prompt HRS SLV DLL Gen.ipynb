# %% [markdown]
# # Prompt:
# You are a Databricks data analyst and have been tasked to create the SQL DDL statement for a Silver level delta table.
#
# The purpose of the table is to store RAND HRS data that is to be used for generating Gold level tables.
#
# You have one document to work with for your task.
#
# > 1. A SQL DDL Template with details about the DDL definition rules.
# >> - `\hrs_dbx_repo\docs\Templates and Workflows\06 HRS DDL Master Template.ipynb`
#
# Only use the single document provided.  Do not use any other document for your work.
#
#
# # Template Inputs:
#
# Use the information below to update the Parameters Values in the template.
#
# The template section and parameter values are provided here.
#
# ## 5.1 User-Supplied Parameters
#
# | Parameter                | Value                               | Parameter Usage
# | ------------------------ | ----------------------------------- | --------------------------------------------------|
# | TARGET_TABLE_NAME        | `fact_demographics_v2`              | Identifies the target table name.                 |
# | TARGET_TABLE_DESCRIPTION | `RAND HRS demographics fact table.` | Provides the target table's business description. |
#
# ## 7.5 Target Business Columns and Source Mapping Metadata
#
# The following business columns must be added to in the target table.
#
# | Target Column | Databricks Type | Nullable | Description                      | RAND Source Variable  | RAND Type       |
# | ------------- | --------------- | -------- | -------------------------------- | --------------------- | ----------------|
# | `agey_e`      | `DECIMAL(10,2)` | Yes      | Respondent age                   | `R{n}AGEY_E`          | `DECIMAL(10,2)` |
# | `cenreg`      | `TINYINT`       | Yes      | Census region                    | `R{n}CENREG`          | `CATEG`         |
# | `mstat`       | `TINYINT`       | Yes      | Marital status                   | `R{n}MSTAT`           | `CATEG`         |
# | `raracem`     | `TINYINT`       | Yes      | RAND HRS race classification     | `RARACEM`             | `CATEG`         |
# | `rahispan`    | `TINYINT`       | Yes      | RAND HRS Hispanic classification | `RAHISPAN`            | `CATEG`         |
# | `raedyrs`     | `TINYINT`       | Yes      | Years of education               | `RAEDYRS`             | `CATEG`         |
# | `rarelig`     | `TINYINT`       | Yes      | Religion                         | `RARELIG`             | `CATEG`         |
# | `ravetrn`     | `TINYINT`       | Yes      | Veteran status                   | `RAVETRN`             | `CATEG`         |
