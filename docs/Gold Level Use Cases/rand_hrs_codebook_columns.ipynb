# %% [markdown]
# # Demographics
# | Target Column | Source Variable Confirmed | Label (from codebook) | Coding Range |
# | --- | --- | --- | --- |
# | agey_e | R1AGEY_E...R16AGEY_E ✓ | R Age (years) at Ivw EndMon | 23.0–85.0 (Cont) |
# | raracem | RARACEM ✓ | R Race-masked | 1.0–3.0 (Categ, wave-invariant) |
# | rahispan | RAHISPAN ✓ | R Hispanic | 0.0–1.0 (Categ, wave-invariant) |
# | cenreg | R1CENREG...R16CENREG ✓ | Census Region | 1.0–5.0 (Categ) |
# | raedyrs | RAEDYRS ✓ | R Years of Education | 0.0–17.0 (Categ, wave-invariant) |
# | mstat | R1MSTAT...R16MSTAT ✓ | R Marital Status | 1.0–8.0 (Categ) |
# | rarelig | RARELIG ✓ | R Religion | 1.0–5.0 (Categ, wave-invariant) |
# | ravetrn | RAVETRN ✓ | R Veteran Status | 0.0–1.0 (Categ, wave-invariant) |

# %% [markdown]
# # Health
# | Target Column | Source Variable Confirmed | Label (from codebook) | Coding Range |
# | --- | --- | --- | --- |
# | shlt | R1SHLT...R16SHLT ✓ | Self-report of health | 1.0–5.0 (Categ) |
# | bmi | R1BMI...R16BMI ✓ | Self-reported body mass index=kg/m2 | 12.8–102.7 (Cont) |
# | hibpe | R1HIBPE...R16HIBPE ✓ | R ever had high blood pressure | 0.0–1.0 (binary) |
# | diabe | R1DIABE...R16DIABE ✓ | R ever had diabetes | 0.0–1.0 (binary) |
# | cancre | R1CANCRE...R16CANCRE ✓ | R ever had cancer | 0.0–1.0 (binary) |
# | lunge | R1LUNGE...R16LUNGE ✓ | R ever had lung disease | 0.0–1.0 (binary) |
# | hearte | R1HEARTE...R16HEARTE ✓ | R ever had heart problems | 0.0–1.0 (binary) |
# | stroke | R1STROKE...R16STROKE ✓ | R ever had stroke | 0.0–1.0 (binary) |
# | psyche | R1PSYCHE...R16PSYCHE ✓ | R ever had psych problems | 0.0–1.0 (binary) |
# | arthre | R1ARTHRE...R16ARTHRE ✓ | R ever had arthritis | 0.0–1.0 (binary) |
