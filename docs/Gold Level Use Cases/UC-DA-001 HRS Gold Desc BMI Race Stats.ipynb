# %% [markdown]
# ### Use Case: UC-DA-001 HRS Gold Desc BMI Race
#
# # Use Case ID: UC-DA-001
#
# # Use Case Name: HRS Gold Desc BMI Race Stats
#
# # Business Queston
#
# `How do BMI statistics vary by wave, race, gender, age and HRS cohort?`
#
# ## Business Objective
#
# Analyze BMI and Age Distribution of a Sample Population Using the RAND HRS Longitudinal Dataset.
#
# Enable researchers, students, and analysts to use the RAND Health and Retirement Study (HRS) Longitudinal Dataset to perform descriptive statistical analysis on Body Mass Index (BMI), for a selected sample population. The analysis will provide insights into the central tendency and variability of these health measures and support comparisons across race and ethnicity.
#
# ### Core Definitions
# - Measures: The raw, fundamental data points or simple numeric values with no added context (e.g., total dollar amount of a single sale, or a count of 500 website visits).
#
# - Metrics: A standard calculation or aggregation of one or more measures that provides operational context, such as an average, ratio, or rate (e.g., Average Order Value calculated by total revenue divided by the number of orders).
#
# - KPIs (Key Performance Indicators): A high-level, critical subset of metrics explicitly tied to a specific business objective, target, and timeframe (e.g., reaching $50,000 in monthly recurring revenue by the end of the quarter).
#
# ### The Data Pipeline
#     [ KPI ]       <-- The Strategic Target (The "Key" Metric)
#         ↑
#     [ Metric ]    <-- The Operational Calculation (Ratios, Rates, Averages)
#         ↑
#     [ Measure ]   <-- The Raw Ingredients (Counts, Time, Currency)
#
# ## Actors
# - Data Analyst
# - Public Health Researcher
# - Epidemiologist
# - Student
#
# ## Supporting Systems
# - Databricks
# - RAND HRS Longitudinal Dataset
# - Delta Lake
# - SQL Warehouse (optional)
# - Python (Pandas, NumPy, Matplotlib)
#
# ## Trigger
# The analyst selects a population sample from the RAND HRS dataset and requests descriptive statistical analysis.
#
# ## Preconditions
# - The RAND HRS Longitudinal Data set has been obtained and is accessible to the user.-
# - RAND HRS data has been loaded into Databricks.
# - Demographic and Health variables have been standardized.
# - BMI and Age variables are available for the selected survey wave(s).
# - Missing or invalid values have been identified.
# - The user has access to statistical software capable of performing descriptive statistics and data visualization.
# - The dataset includes valid, non-null values for BMI, Age, and Race variables.
# - The user has defined the sample population (e.g., filtered by wave/year, demographic criteria, or study cohort).
# - The user has basic knowledge of statistical concepts and software navigation.
#
# ## Postconditions
# The analyst receives:
# - Measures of central tendency
# - Measures of dispersion statistics for BMI and Age are calculated and documented.
# - A comparative interpretation of the strengths/weaknesses of each measure is produced.
# - A visual chart displaying mean BMI by race is generated.
# - Findings are available for reporting, further analysis, or decision-making.
# - Summary report
#
# ## Business Rules
# - BMI values should be validated against realistic physiological ranges (e.g., 10–80) before analysis.
# - Age values should be validated against the RAND HRS study population range (typically 50+ years).
# - Race/Ethnicity categories must follow RAND HRS coding conventions for consistency.
# - All statistical calculations must use complete-case analysis unless imputation is explicitly specified.
#
# ## Functional Requirements Addressed
#
# - FR-1 Measures - Select Population
#     - List of the Gold Table columns mapped to the source RAND HRS variables required to calculate the Metrics.
#
#     | Gold Table Measures | Source Variable      | Description                                | Type  | Codebook Section |
#     | ------------------- | -------------------- |------------------------------------------- | ------| -----------------|
#     | WAVE_NUMBER         | `Derived`            | 16 waves embedded in the HRS variable names| Categ | All              |
#     | AGEY_E              | R1AGEY_E - R16AGEY_E | Waves 1-16 R Age (years) at Ivw EndMon     | Cont  | Demographics     |
#     | RAGENDER            | RAGENDER             | Gender                                     | Categ | Demographics     |
#     | RARACEM             | RARACEM              | Race-masked                                | Categ | Demographics     |
#     | RAHISPAN            | RAHISPAN             | Hispanic Ethnicity                         | Categ | Demographics     |
#     | HACOHORT            | HACOHORT             | Cohorts 1 - 8                              | Categ | Demographics     |
#     | MSTAT               | R1MSTAT              | W1 R Marital Status                        | Categ | Demographics     |
#     | BMI                 | R1BMI                | W1 Self-reported body mass index=kg/m2     | Categ | Health           |
#
#     - Example
#         - Wave = 2020
#         - Age >= 50
#         - Race = Hispanic
#
# - FR-2: Metrics - System/user shall calculate mode, median, and mean for BMI.
# - FR-3: Metrics - System/user shall calculate mode, median, and mean for Age.
# - FR-4: Metrics - System/user shall calculate range, variance, and standard deviation for BMI and Age.
# - FR-5: Metrics - System/user shall support comparative interpretation of measures' strengths/weaknesses.
# - FR-6: Metrics - System/user shall produce a graph of mean BMI segmented by race/ethnicity.
# - FR-7: Compare Statistical Metrics - The user/system shall explain the strengths and weaknesses of each statistic.
#
# | Statistics         | Strengths                         | Weaknesses                                  |
# |--------------------|-----------------------------------|---------------------------------------------|
# | Mean               | Uses all observations             | Sensitive to outliers                       |
# | Median             | Resistant to outliers             | Does not use every value                    |
# | Mode               | Easy to understand                | May not exist or may have multiple values   |
# | Range              | Very easy to calculate            | Uses only two observations                  |
# | Variance           | Measures total variability        | Difficult to interpret due to squared units |
# | Standard Deviation | Widely used and easy to interpret | Sensitive to outliers                       |
#
# ## Non-Functional Requirements
# - Accuracy: Statistical calculations must match validated formulas (e.g., population vs. sample variance distinctions).
# - Usability: Output should be clearly labeled and interpretable by users with basic statistical literacy.
# - Performance: Calculations should complete within acceptable time even for large HRS sample sizes (10,000+ records).
#
# ## Sample Interpretation Notes (Expected Analytical Output)
# - Mean vs. Median for BMI: If BMI distribution is right-skewed (common in health data due to obesity outliers), the mean will be higher than the median — median may better represent "typical" BMI.
# - Mode limitations: BMI, being continuous, may show no meaningful mode or multiple modes unless binned into categories (e.g., underweight, normal, overweight, obese).
# - Age distribution: Likely more symmetric in HRS given age-eligibility criteria (50+), so mean and median may be closer.
# - Standard Deviation vs. Variance: Standard deviation is preferred for interpretability (same units as BMI/Age), while variance is more useful mathematically (e.g., in ANOVA).
# - Range limitation: Sensitive to extreme outliers; does not describe distribution shape.
#
# # Aggregated Measures and Dimensions
#
# ## Dimension
# 1. Cohort
# 2. Wave
#
# ## Measures groups by Cohort, Wave, Age, and Race
# 1. Age
# 2. Age_Number
# 3. Age_Mean
# 4. Age_Standard_Diviation
# 5. Age_Min
# 6. Age_Max
# 7. BMI
# 8. BMI_Number
# 9. BMI_Mean
# 10. BMI_Standard_Diviation
# 11. BMI_Min
# 12. BMI_Max
