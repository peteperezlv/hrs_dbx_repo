# %% [markdown]
# HRS Raw Data Ingestion
#
# Setp 1 - Setup Secrets in Databricks for the RAND UserName and Password.
#
# Step 2 - Download the RAND Logitudinal Health and Retirement Study (HRS) Zip File.
#
# Step 3 - Unzip the file
#
# Step 4 - Convert the SPSS file to Parquet in small chuncks to minimize CPU and Memory Costs
#
# Step 5 - Convert the Parquet data to a Delta table
#
# Setp 6 - Create a Workflow/Pipeline to execute the data ingestion: Steps 2 to 4
#
# Step 7 - Test the data ingestion steps.
