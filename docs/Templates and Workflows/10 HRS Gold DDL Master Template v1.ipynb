# %% [markdown]
# # HRS Gold Layer DDL Master Functional Specification
# ## Table of Contents
#
# | # | Section | Category |
# | --- | --- | --- |
# | 1 | [Specification Document Information](#1-specification-document-information) | 🟢 Confirm |
# | 2 | [Template Instructions](#2-template-instructions) | 🟡 Master |
# | 3 | [Purpose](#3-purpose) | 🟡 Master |
# | 4 | [Gold Layer Role](#4-gold-layer-role) | 🟡 Master |
# | 5 | [Analytical Use Case](#5-analytical-use-case) | 🔵 User Input |
# | 6 | [Gold Table Grain](#6-gold-table-grain) | 🔵 User Input |
# | 7 | [Gold Table Type](#7-gold-table-type) | 🔵 User Input |
# | 8 | [Parent Table Parameters](#8-parent-table-parameters) | 🟢 Confirm |
# | 9 | [Target Table Parameters](#9-target-table-parameters) | 🔵 / 🟢 |
# | 10 | [Gold Table Design](#10-gold-table-design) | 🟡 Master |
# | 11 | [Key Strategy](#11-key-strategy) | 🟢 Confirm |
# | 12 | [Table Columns Definitions](#12-table-columns-definitions) | 🔵 User Input |
# | 13 | [Derived Analytical Columns](#13-derived-analytical-columns) | 🔵 User Input |
# | 14 | [Parent-Child Relationships](#14-parent-child-relationships) | 🟢 Confirm |
# | 15 | [Target Foreign Keys](#15-target-foreign-keys) | 🟢 Confirm |
# | 16 | [Natural Identifier Relationship](#16-natural-identifier-relationship) | 🟢 Confirm |
# | 17 | [Table Constraints](#17-table-constraints) | 🔵 User Input |
# | 18 | [Audit Columns](#18-audit-columns) | 🟢 Confirm |
# | 19 | [DROP TABLE Requirement](#19-drop-table-requirement) | 🔵 User Input |
# | 20 | [Physical Table Requirements](#20-physical-table-requirements) | 🟡 Master |
# | 21 | [SQL Generation Requirements](#21-sql-generation-requirements) | 🟡 Master |
# | 22 | [DDL-Only Requirement](#22-ddl-only-requirement) | 🟡 Master |
# | 23 | [Unsupported Objects](#23-unsupported-objects) | 🟡 Master |
# | 24 | [DDL / DML Separation](#24-ddl--dml-separation) | 🟡 Master |
# | 25 | [Structural Validation Requirements](#25-structural-validation-requirements) | 🔵 / 🟢 |
# | 26 | [DDL Workflow](#26-ddl-workflow) | 🟡 Master |
# | 27 | [DDL Deliverable](#27-ddl-deliverable) | 🟡 Master |
# | 28 | [AI DDL Generation Instructions](#28-ai-ddl-generation-instructions) | 🟡 Master |
# | 29 | [Final Specification Checklist](#29-final-specification-checklist) | 🟢 Confirm |
# | 30 | [What Does NOT Belong in This Specification?](#30-what-does-not-belong-in-this-specification) | 🟡 Master |
# | 31 | [Gold DDL → Gold DML Handoff](#31-gold-ddl--gold-dml-handoff) | 🟡 Master |
# | 32 | [Template Usage](#32-template-usage) | 🟡 Master |
# | 33 | [Architectural Principle](#33-architectural-principle) | 🟡 Master |
#
# ---
#
# # 1. Specification Document Information
#
# ### 🟢 CONFIRM
#
# | Property           | Value                                              |
# | ------------------ | -------------------------------------------------- |
# | Document Name      | HRS Gold Layer DDL Master Functional Specification |
# | Version            | 1.0                                                |
# | Author             | `<AUTHOR>`                                         |
# | AI Assistant       | ChatGPT and Claude                                 |
# | Last Updated       | Today's Date                                       |
# | Target Platform    | Databricks                                         |
# | Compute            | Serverless                                         |
# | Runtime            | client.5.12                                        |
# | SQL Dialect        | Databricks SQL / Spark SQL                         |
# | Storage Format     | Delta                                              |
# | Specification Type | DDL Only                                           |
# | Target Data Layer  | Gold                                               |
# | Primary Purpose    | Curated analytical and visualization data          |
#
# ---
#
# # 2. Template Instructions
#
# ### 🟡 MASTER CONTROLLED
#
# This master template defines the requirements for generating a **Gold-layer Databricks SQL DDL script**.
#
# The template uses three categories.
#
# | Category                 | Meaning                                         | User Action                               |
# | ------------------------ | ----------------------------------------------- | ----------------------------------------- |
# | 🔵 **USER INPUT**        | Information specific to the analytical use case | Complete or modify                        |
# | 🟢 **CONFIRM**           | Standard project requirement                    | Review and confirm                        |
# | 🟡 **MASTER CONTROLLED** | HRS architecture requirement                    | Do not modify unless architecture changes |
#
# ### User Process
#
# 1. Complete all 🔵 **USER INPUT** sections.
# 2. Review all 🟢 **CONFIRM** sections.
# 3. Leave all 🟡 **MASTER CONTROLLED** sections unchanged.
# 4. Submit the completed specification for DDL generation.
#
# ### **USER INPUT** sections
#
#
# ---
#
# # 3. Purpose
#
# ### 🟡 MASTER CONTROLLED
#
# This specification defines the requirements for generating a Databricks SQL DDL script for a **Gold-layer analytical table**.
#
# Gold tables contain curated data designed for analytical consumption, including:
#
# * Data analytics
# * Business intelligence
# * Reporting
# * Dashboards
# * Data visualization
# * Statistical analysis
# * Public health analysis
# * Policy analysis
#
# The generated DDL must create the physical Gold Delta table required by the analytical use case.
#
# The Gold table should contain only the structural elements required to support the defined analytical purpose.
#
# ## The KPI Pyramid
# ```text
#
#           / \
#          /   \
#         / kpi \ A high-level subset of metrics explicitly tied to a specific business objective, target, and timeframe.
#        /-------\
#       / Metrics \ Calculation or aggregation of one or more measures that provides operational context, ie.e Avg, ratio,
#      /-----------\
#     /  Measures   \ The raw, fundamental data points or simple numeric values with no added context.
#    /-------------- \
#   /  Biz Question   \ The core problem or specific operational doubt that the analysis, tool, or system is designed to answer.
#   -------------------
# ```
#
#
# ### DDL Responsibility
#
# The DDL specification defines:
#
# > **What the Gold table looks like.**
#
# It does not define:
#
# > **How data is transformed or loaded into the Gold table.**
#
# ---
#
# # 4. Gold Layer Role
#
# ### 🟡 MASTER CONTROLLED
#
# The Gold layer represents the **consumption and analytical layer** of the HRS data architecture.
#
# ```text
# RAND HRS Dataset
#        │
#        ▼
# Bronze Layer
# Raw / Source Data
#        │
#        ▼
# Silver CDM
# Standardized Relational Data
#        │
#        ▼
# Gold Layer
# Curated Analytical Data
#        │
#        ├───────────────┐
#        ▼               ▼
#    Analytics       Visualization
#        │               │
#        └───────┬───────┘
#                ▼
#         Policy Insights
# ```
#
# Gold tables should be designed around **analytical requirements**, rather than simply reproducing Silver CDM tables.
#
# ---
#
# # 5. Analytical Use Case
#
# ### 🔵 USER INPUT
#
# Every Gold table must have a clearly defined analytical purpose.
#
# | Property          | Value                                                    |
# | ----------------- | -------------------------------------------------------- |
# | Use Case Document | `<USE_CASE_DOCUMENT_PATH>`                               |
# | Use Case ID       | <placeholder - fill in value from the Use Case Document> |
# | Use Case Name     | <placeholder - fill in value from the Use Case Document> |
# | Use Case Document | <placeholder - fill in value from the Use Case Document> |
# | Business Question | <placeholder - fill in value from the Use Case Document> |
# | Primary Users     | <placeholder - fill in value from the Use Case Document> |
# | Intended Use      | placeholder - fill in value from the Use Case Document>  |
#
# ## 5.1 Business Question
#
# Describe the analytical question that the Gold table is intended to support.
#
# **Example:**
#
# > How do BMI statistics vary by race, gender, and HRS cohort?
#
# **User Action:** Replace the example with the actual business question.
#
# ---
#
# # 6. Gold Table Grain
#
# ### 🟢 **CONFIRM**
#
# The Gold table grain defines what **one row represents**.
#
# - cohort_id + wave_id + raracem + ragender + agey_e
#
# ### Grain Requirement
#
# The generated DDL must support the specified analytical grain.
#
# The specification must identify the columns that collectively define the analytical observation.
#
# ---
#
# # 7. Gold Table Type Properties
#
# ### 🔵 USER INPUT
# **User Action:** Select the appropriate table type and describe the table characteristics.
#
# **User Action:** Identify the intended Gold table type and describe the table characteristics.
#
# | Property           | Value       |
# | ------------------ | ----------- |
# | GOLD_TABLE_TYPE    | `<TYPE>`    |
# | ANALYTICAL_ROLE    | `<ROLE>`    |
# | ANALYTICAL_PURPOSE | `<PURPOSE>` |
#
# ## Table type definitions.
# ### 🟡 MASTER CONTROLLED
#
# | Table Type     | Overview   |
# | -------------- | ---------- |
# | **Fact**       | Stores measurable business or analytical events, often at a defined grain such as respondent × wave. Typically contains **foreign keys to dimensions plus measures** such as counts, averages, or totals.                                                            |
# | **Dimension**  | Stores descriptive attributes used to **categorize, filter, group, and provide context** for facts. Examples include cohort, wave, race, gender, or geography.                                                                                                       |
# | **Aggregate**  | Stores **pre-calculated summaries** of data to improve analytical performance or simplify reporting. Typically contains grouping dimensions plus calculated measures such as count, mean, min, or max.                                                               |
# | **Analytical** | A broader category for a table specifically designed to answer an **analytical question or support a particular use case**. It may combine dimensions, measures, and derived attributes and does not necessarily follow a strict star-schema fact/dimension pattern. |
#
# ## 7.1 Gold Table Naming Convention
#
# ### 🟡 MASTER CONTROLLED
#
# Gold table names should follow this convention.
# | Table Type     | Naming Convention  |
# | -------------- | ------------------ |
# | **Fact**       | `fact_<subject>`   |
# | **Dimension**  | `dim_<subject>`    |
# | **Aggregate**  | `aggregate_<subject>` |
# | **Analytical** | `analytic_<subject>` |
#
# ---
#
# # 8. Parent Table Parameters
#
# ### 🟢 CONFIRM
#
# This section identifies the parent data tables.
#
# Although the source table is not used directly to generate the physical DDL structure in every case, it provides the source-data context for the target table and its foreign key relationships.
#
# The parameter table contains two columns:
#
# 1. **Parameter** — The name of the parameter. Parameter names may be referenced in subsequent sections.
# 2. **Value** — The value assigned to the parameter.
#
# The following parameters normally remain unchanged unless:
# * The parent table or its location changes
# * New parent table are introduced into the model
#
# | Parameter Name          | Category      | Value            |
# | ----------------------- | ------------- | ---------------- |
# | PARENT_TABLE_WAVE       | 🟢 Confirm    | dim_wave         |
# | PARENT_TABLE_COHORT     | 🟢 Confirm    | dim_cohort       |
# | PARENT_CATALOG          | 🟢 Confirm    | dev_catalog      |
# | PARENT_SCHEMA           | 🟢 Confirm    | slv_cdm_hrs      |
#
#
# The SQL generator must not assume that the source and target catalog/schema are necessarily the same.
#
# # 9. Target Table Parameters
#
# ### 🔵 USER INPUT / 🟢 CONFIRM
#
# This section defines the physical Gold table.
#
# User enters the `TARTGET_TABLE_NAME` and `TARGET_TABLE_COMMENT` in the Value column.
#
# | Parameter                | Category       | Value           |
# | ------------------------ | -------------- | --------------- |
# | TARGET_TABLE_NAME        | 🔵 User Input | `<TABLE_NAME>`  |
# | TARGET_TABLE_COMMENT     | 🔵 User Input | `<DESCRIPTION>` |
# | TARGET_CATALOG           | 🟢 Confirm    | dev_catalog`    |
# | TARGET_SCHEMA            | 🟢 Confirm    | gld_star_hrs    |
# | STORAGE_FORMAT           | 🟢 Confirm    | DELTA           |
# | TABLE_TYPE               | 🟢 Confirm    | Managed Table   |
#
#
# ### Target-Table Naming Convention
#
# The generated table must use:
#
# ```text
# <TARGET_CATALOG>.<TARGET_SCHEMA>.<TARGET_TABLE_NAME>
# ```
#
# Examples:
#
# ```text
# | TARGET_TABLE_NAME      | 🔵 User Input |analytic_hrs_bmi_race                                                                 |
# | PARENT_TABLE_COMMENT   | 🔵 User Input |`BMI descriptive statistics table grouped by HRS cohort, wave, race, gender, and age` |
# etc.
# ```
#
# ---
#
# # 10. Gold Table Design
#
# ### 🟡 MASTER CONTROLLED
#
# Define the physical structure required by the analytical use case.
#
# The Gold table may contain:
#
# * Analytical dimensions
# * Analytical measures
# * Identifiers
# * Foreign keys
# * Derived analytical attributes
# * Audit columns
#
#
# # 11. Primary Key Strategy
#
# ### 🟡 MASTER CONTROLLED
#
# The surrogate key is generated by Databricks.
#
# The analytical/business key identifies the statistical observation.
#
# ### Key Design Rule
#
# If a surrogate primary key is required, it should normally be implemented as:
#
# ```sql
# BIGINT GENERATED ALWAYS AS IDENTITY
# ```
#
# ---
#
# # 12. Table Columns Definitions
#
# ### Column Rule
#
# The DDL generator must create **only the columns defined in this matrix**.
#
# The generator must not invent additional columns.
#
# ## 12.1 Keys Business Attributes, and Audit Columns
#
# ### 🔵 USER INPUT
#
# User update the PK, FK, and Business Column Names and Comments. Add only columns required for the Use Case.
#
# | Column Name             | Category             | Databricks Type | Nullable | Column Comment                  |
# |------------------------ | -------------------- | --------------- | -------- |-------------------------------- |
# | <TARGET_TABLE_NAME>_ID  | Primary Key          | BIGINT          | No       | System-generated surrogate key  |
# | <PARENT_TABLE_WAVE>_ID  | Foreign Key          | BIGINT          | No       | `<Foreign key Description>`     |
# | <PARENT_TABLE_COHORT>_ID| Foreign Key          | BIGINT          | No       | `<Foreign key Description>`     |
# | `<Biz COLUMN 1>`        | Business Attribute 1 | INT             | Yes      | `<Biz Col Description>`         |
# | `<Biz COLUMN 2>`        | Business Attribute 1 | INT             | Yes      | `<Biz Col Description>`         |
# | create_date             | Audit                | DATE            | No       | Record creation date            |
# | update_date             | Audit                | DATE            | No       | Last update date                |
# | active                  | Audit               | BOOLEAN          | No       | Active indicator                |
#
# Examples:
#
# ```text
# analytic_hrs_bmi_race_gender_stats_id
# wave_id
# cohort_id
# etc.
# ```
#
# These are examples only.
# ---
# ## 12.2 Dimension Columns
#
# ### 🔵 USER INPUT
#
# User provides the dimension columns.  These are columns the define the table grain.
#
# The Use Case may require zero, one, or man dimensions.
#
# | Column Name      | Category           | Databricks Type | Nullable | Column Comment                  |
# |----------------- | ------------------ | --------------- | -------- |-------------------------------- |
# | `Dim Column 1`   | Dimension          | INT             | Yes      | `Dim Column 1 Description`      |
# | `Dim Column 2`   | Dimension          | INT             | Yes      | `Dim Column 2 Description`      |
# | `Dim Column 3`   | Dimension          | INT             | Yes      | `Dim Column 3 Description`      |
#
# Examples:
#
# ```text
# raracem
# ragender
# agey_e
# etc.
# ```
#
# These are examples only.
#
# ---
#
# # 12.3 Metric Columns
#
# ### 🔵 USER INPUT
#
# Define the physical measure columns required by the Gold table.
#
# | Column Name       | Category        | Databricks Type | Nullable | Column Comment                  |
# |------------------ | --------------- | --------------- | -------- |-------------------------------- |
# | `Metric Column 1` | Metric          | INT             | Yes      | `Metric Column 1 Description`   |
# | `Metric Column 2` | Metric          | INT             | Yes      | `Metric Column 2 Description`   |
# | `Metric Column 3` | Metric          | INT             | Yes      | `Metric Column 3 Description`   |
#
#
# Examples:
#
# ```text
# bmi_mean,
# bmi_min,
# bmi_max,
# bmi_median,
# bmi_count,
# etc.
# ```
#
# These are examples only.
#
# ---
#
# # 13. Derived Analytical Columns
#
# ### 🔵 USER INPUT
#
# Identify any columns that are derived for analytical purposes.
#
# | Column Name | Databricks Type | Nullable     | Description     |
# | ----------- | --------------- | ------------ | --------------- |
# | `<COLUMN>`  | `<TYPE>`        | `<YES / NO>` | `<DESCRIPTION>` |
#
# If no derived columns are required:
#
# ```text
# Derived Analytical Columns Required: No
# ```
#
# ### Important
#
# A derived column is a column whose value is computed or categorized from other data, rather than being a direct pass-through of a source variable or a straightforward statistical aggregate.
#
# In the context of this spec template, it specifically means things like:
#
# * age_group — bucketing a continuous age value into categories like "18-34", "35-54", "55+"
# * income_group — bucketing income into tiers
# * health_risk_category — classifying a health score into "low/medium/high risk"
#
# The common thread is business logic applied to transform or categorize a value — usually collapsing a continuous or granular variable into something more analyst-friendly (buckets, flags, classifications, calculated ratios, etc.).
#
# It's a distinct concept from a few things it's easy to confuse it with:
#
# * Not a raw source column — a derived column doesn't exist as-is in the Silver layer; it's computed during the Gold transformation.
# * Not the same as an aggregate/measure — bmi_mean, bmi_sd, for example, are statistical aggregates (computed via AVG(), STDDEV(), etc. across a group), not derived categorical attributes. That's why I would classify them as Measures (Section 12) rather than Derived Analytical Columns in the spec. The examples given (age_group, income_group, risk_category) are about categorization/bucketing, not aggregations.
#
# ---
#
# # 14. Parent-Child Relationships
# This section defines the parent tables and relationships required by the target table.
#
# The target table references **system-generated surrogate keys** from the parent tables.
#
# The source natural identifiers are separate from the parent surrogate keys.
#
# If no parent tables are required:
#
# ```text
# Parent Table Dependencies: None
# ```
#
# ### 🟢 CONFIRM
#
# | Parent Table          | Child Table                                                    | Relationship |
# | --------------------- | -------------------------------------------------------------- | ------------ |
# | <PARENT_TABLE_WAVE>   | <TARGET_CATALOG_NAME>.<TARGET_SCHEMA_NAME>.<TARGET_TABLE_NAME> | One-to-Many  |
# | <PARENT_TABLE_COHORT> | <TARGET_CATALOG_NAME>.<TARGET_SCHEMA_NAME>.<TARGET_TABLE_NAME> | One-to-Many  |
#
# From the target-table perspective, each relationship is many-to-one.
#
# # 15. Target Foreign Keys
#
# ### 🟢 CONFIRM
#
# | Target FK Column | Parent Table          | Parent Primary Key    |
# | ---------------- | --------------------- | --------------------- |
# | wave_id          | <PARENT_TABLE_WAVE>   | wave_id               |
# | cohort_id        | <PARENT_TABLE_COHORT> | cohort_id             |
#
# The generated DDL must establish these relationships using foreign-key constraints.
#
# ## Foreign Key Constrain Naming Convention:
#
# The foreign key constraints must follow this pattern.
#
# * fk_<TARGET_TABLE_NAME>_<PARENT_TABLE_WAVE>
# * fk_<TARGET_TABLE_NAME>_<PARENT_TABLE_COHORT>
#
# The DDL generator must create the specified foreign-key constraints.
#
# The DDL does **not** define how the foreign-key values are populated.
#
# That logic belongs in the DML specification.
#
# # 16. Natural Identifier Relationship
# ### 🟢 CONFIRM
#
# | Natural Identifier | Parent Table          | Parent Surrogate Key |
# | ------------------ | --------------  ----- | -------------------- |
# | wave_number        | <SOURCE_TABLE_WAVE>   | wave_id              |
# | HACOHORT           | <SOURCE_TABLE_COHORT> | cohort_id            |
#
# The mechanism used to resolve these natural identifiers to surrogate keys is outside the scope of this DDL specification.
#
# ---
#
# # 17. Table Constraints
#
# ### 🟢 CONFIRM
#
# Define the structural constraints required by the Gold table.
#
# | Constraint Type | Required     |
# | --------------- | ------------ |
# | PRIMARY KEY     | `YES`        |
# | FOREIGN KEY     | `YES`        |
#
# ### Business Key / Uniqueness
#
# If applicable, define the columns that must be unique.
#
# ```text
# Business Key Required? No
# ```
# ---
#
# # 18. Audit Columns
#
# ### 🟢 CONFIRM
#
# The standard HRS Gold audit columns are:
#
# | Column      | Type    | Nullable | Description          |
# | ----------- | ------- | -------- | -------------------- |
# | create_date | DATE    | No       | Record creation date |
# | update_date | DATE    | No       | Last update date     |
# | active      | BOOLEAN | No       | Active indicator     |
#
# Confirm whether these columns are required for the specific Gold table.
#
# ```text
# Audit Columns Required: <YES / NO>
# ```
#
# ---
#
# # 19. DROP TABLE Requirement
#
# ### 🔵 USER INPUT
#
# Determine whether the development DDL should recreate the table.
#
# | Requirement          | Value        |
# | -------------------- | ------------ |
# | DROP TABLE IF EXISTS | `<YES / NO>` |
#
# ### Warning
#
# `DROP TABLE IF EXISTS` is destructive and should only be used when permitted by
#
# # 20. Physical Table Requirements
#
# ### 🟡 MASTER CONTROLLED
#
# The generated Gold table must:
#
# * Use Delta storage.
# * Be a Managed Table.
# * Use the specified catalog.
# * Use the specified schema.
# * Use the specified table name.
# * Use explicit column definitions.
# * Use specified data types.
# * Use specified nullability.
# * Use specified keys and constraints.
# * Include a table comment.
# * Include column comments.
#
# ---
#
# # 21. SQL Generation Requirements
#
# ### 🟡 MASTER CONTROLLED
#
# The generated SQL must:
#
# 1. Use Databricks SQL / Spark SQL.
# 2. Be compatible with the specified serverless environment.
# 3. Target runtime `client.5.12`.
# 4. Use uppercase SQL keywords.
# 5. Use consistent indentation.
# 6. Use explicit column definitions.
# 7. Use the specified catalog.
# 8. Use the specified schema.
# 9. Use the specified table name.
# 10. Use Delta storage.
# 11. Create a Managed Table.
# 12. Apply specified constraints.
# 13. Include required comments.
# 14. Use only DDL statements.
#
# ---
#
# # 22. DDL-Only Requirement
#
# ### 🟡 MASTER CONTROLLED
#
# The generated script must contain **DDL only**.
#
# Allowed examples include:
#
# ```text
# DROP TABLE
# CREATE TABLE
# ALTER TABLE
# ```
#
# Only generate statements explicitly required by the specification.
#
# Do not generate data-loading or transformation logic.
#
# ---
#
# # 23. Unsupported Objects
#
# ### 🟡 MASTER CONTROLLED
#
# The DDL generator must not create:
#
# ```text
# INSERT
# UPDATE
# DELETE
# MERGE
# SELECT
# VIEWS
# STORED PROCEDURES
# FUNCTIONS
# INDEXES
# PARTITIONS
# ZORDER
# OPTIMIZE
# ```
#
# DML and analytical transformation logic belong to the corresponding DML specification.
#
# ---
#
# # 24. DDL / DML Separation
#
# ### 🟡 MASTER CONTROLLED
#
# The HRS Gold architecture separates physical table creation from data population.
#
# ```text
# Analytical Use Case
#         │
#         ▼
# Gold DDL Specification
#         │
#         ▼
# Generate DDL
#         │
#         ▼
# Execute DDL
#         │
#         ▼
# Gold Delta Table
#         │
#         ▼
# Validate Structure
#         │
#         ▼
# Gold DML Specification
#         │
#         ▼
# Transform and Load Data
# ```
#
# ### DDL
#
# Defines:
#
# > **What the table looks like.**
#
# ### DML
#
# Defines:
#
# > **How the table is populated.**
#
# The two specifications should not duplicate responsibilities.
#
# ---
#
# # 25. Structural Validation Requirements
#
# ### 🔵 USER INPUT / 🟢 CONFIRM
#
# The generated Gold table should be validated after DDL execution.
#
# | Validation         | Required     |
# | ------------------ | ------------ |
# | Table Exists       | Yes          |
# | Correct Catalog    | Yes          |
# | Correct Schema     | Yes          |
# | Correct Table Name | Yes          |
# | Delta Format       | Yes          |
# | Managed Table      | Yes          |
# | Expected Columns   | Yes          |
# | Data Types         | Yes          |
# | Nullability        | Yes          |
# | Primary Key        | `<YES / NO>` |
# | Foreign Keys       | `<YES / NO>` |
# | Unique Constraints | `<YES / NO>` |
# | Audit Columns      | Yes          |
#
# ### Analytical Grain Validation
#
# The table structure must support the following grain:
#
# For Example:
#
# ```text
# cohort_id
# +
# wave_id
# +
# raracem
# +
# ragender
# +
# agey_e
# ```
#
# The `bmi` column must not exist in the target table.
#
# ---
#
# # 26. DDL Workflow
#
# ### 🟡 MASTER CONTROLLED
#
# The standard Gold DDL workflow is:
#
# ```text
# Analytical Use Case
#         │
#         ▼
# Business Question
#         │
#         ▼
# Define Analytical Grain
#         │
#         ▼
# Define Gold Table Type
#         │
#         ▼
# Define Dimensions
#         │
#         ▼
# Define Measures
#         │
#         ▼
# Define Gold Columns
#         │
#         ▼
# Define Keys and Constraints
#         │
#         ▼
# Complete DDL Specification
#         │
#         ▼
# Generate DDL
#         │
#         ▼
# Review Generated SQL
#         │
#         ▼
# Execute in Databricks
#         │
#         ▼
# Validate Gold Table
#         │
#         ▼
# Begin Gold DML Specification
# ```
#
# ---
#
# # 27. DDL Deliverable
#
# ### 🟡 MASTER CONTROLLED
#
# The generated SQL file should follow the repository convention:
#
# ```text
# /sql/ddl/create_<TARGET_TABLE_NAME>.sql
# ```
#
# For example:
#
# ```text
# /sql/ddl/create_hrs_fact_bmi_race_gender_stats.sql
# ```
#
# The final DDL deliverable must contain:
#
# ```text
# SQL ONLY
# ```
#
# No explanatory text should be included in the SQL deliverable.
#
# ---
#
# # 28. AI DDL Generation Instructions
#
# ### 🟡 MASTER CONTROLLED
#
# Generate a complete Databricks SQL DDL script from this specification.
#
# The generated script must:
#
# 1. Follow this specification exactly.
# 2. Create only the specified Gold table.
# 3. Use the specified catalog, schema, and table name.
# 4. Create only the specified columns.
# 5. Use the specified data types.
# 6. Apply the specified nullability.
# 7. Apply the specified keys and constraints.
# 8. Include the specified table comment.
# 9. Include the specified column comments.
# 10. Follow the specified SQL formatting requirements.
# 11. Use only DDL statements.
# 12. Not generate INSERT statements.
# 13. Not generate UPDATE statements.
# 14. Not generate DELETE statements.
# 15. Not generate MERGE statements.
# 16. Not generate transformation logic.
# 17. Not generate source-to-target mapping logic.
# 18. Not invent columns.
# 19. Not invent constraints.
# 20. Not invent business rules.
# 21. Not infer missing structural requirements.
# 22. Return SQL only.
#
# ### Missing Information Rule
#
# If required information is missing, do not invent the requirement.
#
# Identify the missing information before generating the final DDL.
#
# ---
#
# # 29. Final Specification Checklist
#
# ### 🟢 CONFIRM
#
# Before submitting the specification for DDL generation, confirm:
#
# * [ ] Analytical Use Case defined
# * [ ] Business Question defined
# * [ ] Gold Table Grain defined
# * [ ] Gold Table Type defined
# * [ ] Target Table Name defined
# * [ ] Target Catalog confirmed
# * [ ] Target Schema confirmed
# * [ ] Delta Storage confirmed
# * [ ] Managed Table confirmed
# * [ ] Key Strategy defined
# * [ ] Dimension Columns defined
# * [ ] Measure Columns defined
# * [ ] Derived Columns defined or explicitly excluded
# * [ ] Gold Column Definition Matrix completed
# * [ ] Parent Table Dependencies defined or explicitly excluded
# * [ ] Foreign Key Relationships defined or explicitly excluded
# * [ ] Constraints defined
# * [ ] Audit Columns confirmed
# * [ ] Table Comment defined
# * [ ] Column Comments defined
# * [ ] DROP TABLE requirement confirmed
# * [ ] Structural Validation Requirements defined
# * [ ] Analytical Grain Validation defined
#
# ---
#
# # 30. What Does NOT Belong in This Specification?
#
# ### 🟡 MASTER CONTROLLED
#
# The following information belongs in the **Gold DML Functional Specification**, not the Gold DDL specification:
#
# * Source Silver tables used for loading
# * RAND HRS source variables
# * Source-to-target mappings
# * Source data transformations
# * Lookups
# * Unpivoting
# * Pivoting
# * Aggregations
# * Calculated values
# * Filtering rules
# * Business transformation rules
# * INSERT logic
# * UPDATE logic
# * MERGE logic
# * Data-loading sequence
#
# The DDL specification should remain focused on the **physical structure of the Gold table**.
#
# ---
#
# # 31. Gold DDL → Gold DML Handoff
#
# ### 🟡 MASTER CONTROLLED
#
# The DDL specification is considered complete when the physical Gold table structure has been defined and validated.
#
# The DML specification begins after the DDL structure has been approved.
#
# ```text
#           GOLD DDL
#              │
#              ▼
#       Physical Table
#              │
#              ▼
#        DDL Validation
#              │
#              ▼
#       APPROVED TABLE
#              │
#              ▼
#           GOLD DML
#              │
#              ▼
#      Source + Mapping
#              │
#              ▼
#        Transformation
#              │
#              ▼
#            Load
# ```
#
# The Gold DML specification may reference the approved DDL table structure rather than redefining it.
#
# ---
#
# # 32. Template Usage
#
# ### 🟡 MASTER CONTROLLED
#
# To create a new Gold DDL specification:
#
# ### Step 1 — Identify the Analytical Use Case
#
# Define what the Gold table is intended to support.
#
# ### Step 2 — Define the Grain
#
# Explicitly define what one row represents.
#
# ### Step 3 — Define the Gold Table
#
# Provide the target table name, description, catalog, and schema.
#
# ### Step 4 — Define the Physical Columns
#
# Identify dimensions, measures, keys, and audit columns.
#
# ### Step 5 — Define Keys and Constraints
#
# Identify primary keys, foreign keys, unique constraints, and other structural requirements.
#
# ### Step 6 — Complete the Specification
#
# Complete the 🔵 USER INPUT sections and review the 🟢 CONFIRM sections.
#
# ### Step 7 — Generate DDL
#
# Provide the completed specification to the AI DDL generator.
#
# ### Step 8 — Review the SQL
#
# Confirm that the generated SQL matches the specification.
#
# ### Step 9 — Execute in Databricks
#
# Create the Gold Delta table.
#
# ### Step 10 — Validate
#
# Validate the physical table structure.
#
# ### Step 11 — Begin DML
#
# Once the DDL is approved, create the corresponding Gold DML specification.
#
# ---
#
# # 33. Architectural Principle
#
# ### 🟡 MASTER CONTROLLED
#
# The HRS Gold Layer follows the principle:
#
# > **Define the analytical requirement first, define the physical table second, and define the data-loading process third.**
#
# This produces a controlled separation:
#
# ```text
# Business Requirement
#         │
#         ▼
# Analytical Design
#         │
#         ▼
# Gold DDL
# "What does it look like?"
#         │
#         ▼
# Gold Table
#         │
#         ▼
# Gold DML
# "How is it populated?"
# ```
#
# The result is a reusable, maintainable, and consistent framework for expanding the HRS Gold analytical layer across subject areas such as:
#
# * Demographics
# * Health
# * Financial
# * Employment
# * Retirement
# * Family
# * Housing
# * Social Security
# * Other HRS analytical domains
