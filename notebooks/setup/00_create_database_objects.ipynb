# %%
# Create the HRS COHORT table.  Read the SQL file from the Git repository and execute it .
# notes: 

from src.common.sql_utils import execute_sql_file

execute_sql_file(
    spark,
    "../../sql/ddl/create_hrs_cohort.sql"
)

# %%
# Create the HRS DEMOGRAPHICS table.  Read the SQL file from the Git repository and execute it.

from src.common.sql_utils import execute_sql_file

execute_sql_file(
    spark,
    "../../sql/ddl/create_hrs_demographics.sql"
)

# %%
# Create the HRS HEALTH table.  Read the SQL file from the Git repository and execute it.

from src.common.sql_utils import execute_sql_file

execute_sql_file(
    spark,
    "../../sql/ddl/create_hrs_health.sql"
)

# %%
# Create the RESPONDENT table.  Read the SQL file from the Git repository and execute it.
"""
with open("../sql/ddl/create_respondent.sql") as f:
    sql_statements = f.read().split(";")
# Use this logic to execute multiple SQL statements (DROP and CREATE).  spark.sql() only accepts a single statement at a time.
for statement in sql_statements:
    statement = statement.strip()
    if statement:
        spark.sql(statement)
"""
from src.common.sql_utils import execute_sql_file

execute_sql_file(
    spark,
    "../../sql/ddl/create_hrs_respondent.sql"
)
