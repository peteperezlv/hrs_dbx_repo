# %% [markdown]
# Purpose: partition the HRS raw table into partition to improve query performance.
#
# Partitions: Waves, cohort, survey group (demographics, health, etc.)
#
# Steps:
# 1. Create Partition function (one per Wave or Survey Group for example)
# 2. Create the file groups (one per partition)
# 3. Create the data files (one or more)
# 4. Create the Partition schema
# 5. Create the Partition Table or the Partition Scheme
# 6. Load the Partition Table from the source Raw table
# 7. Test with a Partition Table query (counts)
# 8. Review the exectution plan
