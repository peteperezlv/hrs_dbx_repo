# %%
# Create the COHORT table.  Read the SQL file from the Git repository and execute it.

with open("../sql/ddl/create_cohort.sql") as f:
    sql_statements = f.read().split(";")
# Use this logic to execute multiple SQL statements (DROP and CREATE).  spark.sql() only accepts a single statement at a time.
for statement in sql_statements:
    statement = statement.strip()
    if statement:
        spark.sql(statement)

# %%
# Create the WAVE table.  Read the SQL file from the Git repository and execute it.

with open("../sql/ddl/create_wave.sql") as f:
    sql_statements = f.read().split(";")
# Use this logic to execute multiple SQL statements (DROP and CREATE).  spark.sql() only accepts a single statement at a time.
for statement in sql_statements:
    statement = statement.strip()
    if statement:
        spark.sql(statement)

# %%
# Create the QUESTION table.  Read the SQL file from the Git repository and execute it.

with open("../sql/ddl/create_question.sql") as f:
    sql_statements = f.read().split(";")
# Use this logic to execute multiple SQL statements (DROP and CREATE).  spark.sql() only accepts a single statement at a time.
for statement in sql_statements:
    statement = statement.strip()
    if statement:
        spark.sql(statement)

# %%
# Create the RESPONDENT_TYPE table.  Read the SQL file from the Git repository and execute it.

with open("../sql/ddl/create_respondent_type.sql") as f:
    sql_statements = f.read().split(";")
# Use this logic to execute multiple SQL statements (DROP and CREATE).  spark.sql() only accepts a single statement at a time.
for statement in sql_statements:
    statement = statement.strip()
    if statement:
        spark.sql(statement)

# %%
# Create the RESPONDENT table.  Read the SQL file from the Git repository and execute it.

with open("../sql/ddl/create_respondent.sql") as f:
    sql_statements = f.read().split(";")
# Use this logic to execute multiple SQL statements (DROP and CREATE).  spark.sql() only accepts a single statement at a time.
for statement in sql_statements:
    statement = statement.strip()
    if statement:
        spark.sql(statement)

# %%
# Create the RESPONDENT table.  Read the SQL file from the Git repository and execute it.

with open("../sql/ddl/create_question_response.sql") as f:
    sql_statements = f.read().split(";")
# Use this logic to execute multiple SQL statements (DROP and CREATE).  spark.sql() only accepts a single statement at a time.
for statement in sql_statements:
    statement = statement.strip()
    if statement:
        spark.sql(statement)
